# %% [markdown]
# Цель работы
# - Освоить базовые принципы построения и обучения простой нейронной сети на
# PyTorch.
# - Научиться экспортировать модель в формат ONNX.
# - Изучить структуру модели через граф вычислений с использованием
# инструмента Netron

# %%
# !pip install --upgrade onnx onnxscript onnxruntime
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.20.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Collecting onnxscript
#   Downloading onnxscript-0.5.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (2.0.2)
# Collecting onnx_ir<2,>=0.1.12 (from onnxscript)
#   Downloading onnx_ir-0.1.12-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (25.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->onnxscript) (5.29.5)
# Downloading onnxscript-0.5.6-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.0/683.0 kB 10.7 MB/s eta 0:00:00 0:00:01
# Downloading onnx_ir-0.1.12-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: onnx_ir, onnxscript
# Successfully installed onnx_ir-0.1.12 onnxscript-0.5.6

# %% [markdown]
# # Создание кастомной нейросети

# %% [markdown]
# В качестве запоминания и большего понимания реализую LeNet-5
#
# ![image.png](attachment:image.png)

# %%
# IMPLEMENTATION WITH Sequential

import torch
import torch.nn as nn


class LeNet5(nn.Module):
    def __init__(self):
        '''
        kernel_size = 5 / 2 as in original LeNet-5
        padding = 0 because LeNet-5 didn't have padding
        stride=1 step of kernel during shifting
        '''
        super(LeNet5, self).__init__()
        self.feature_extractor = nn.Sequential(
            # Input 32x32 → Conv5x5 stride1 padding0 → Output 6@28x28  (32-5+1=28)
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=0, stride=1),
            nn.Tanh(),
            # Input 28x28 → Pool2x2 stride2 → Output 14x14 (28/2=14)
            nn.AvgPool2d(kernel_size=2, stride=2),

            # Input 14x14 → Conv5x5 stride1 padding0 → Output 16@10x10  (14-5+1=10)
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0, stride=1),
            nn.Tanh(),
            # Input 10x10 → Pool2x2 stride2 → Output 5x5 (10/2=5)
            nn.AvgPool2d(kernel_size=2, stride=2)
        )

        self.linears = nn.Sequential(
            # Input 16@5x5 -> Output 400
            nn.Linear(400, 120),
            nn.Tanh(),
            nn.Linear(120, 84),
            nn.Tanh(),
            nn.Linear(84, 10),
            # ! Commented finall Softmnax because ONNX has problems with it !
            # nn.Softmax()
        )

    def forward(self, x):
        out = self.feature_extractor(x)
        out = torch.flatten(out, 1)
        out = self.linears(out)
        return out

# %%
# IMPLEMENTATION WITHOUT Sequential

# import torch
# import torch.nn as nn
# import torch.nn.functional as F


# class LeNet5(nn.Module):
#     def __init__(self):
#         '''
#         kernel_size = 5 / 2 as in original LeNet-5
#         padding = 0 because LeNet-5 didn't have padding
#         stride=1 step of kernel during shifting
#         '''
#         super(LeNet5, self).__init__()
#         # Input 32x32 → Conv5x5 stride1 padding0 → Output 6@28x28  (32-5+1=28)
#         self.conv2d1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=0, stride=1)
        
#         # Input 14x14 → Conv5x5 stride1 padding0 → Output 6@10x10  (14-5+1=10)
#         self.conv2d2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0, stride=1)

#         # Input 16@5x5 -> Output 400
#         self.l1 = nn.Linear(400, 120)
#         self.l2 = nn.Linear(120, 84)
#         self.l3 = nn.Linear(84, 10)

#     def forward(self, x):
#         out = self.conv2d1(x)
#         out = F.tanh(out)
#         # Input 28x28 → Pool2x2 stride2 → Output 14x14 (28/2=14)
#         out = F.avg_pool2d(out, kernel_size=2, stride=2)

#         out = self.conv2d2(out)
#         out = F.tanh(out)
#         # Input 10x10 → Pool2x2 stride2 → Output 5x5 (10/2=5)
#         out = F.avg_pool2d(out, kernel_size=2, stride=2)

#         out = torch.flatten(out, 1)

#         out = self.l1(out)
#         out = F.tanh(out)
#         out = self.l2(out)
#         out = F.tanh(out)
#         out = self.l3(out)

#         return out

# %% [markdown]
# # Запуск модели и экспорт в ONNX

# %%
lenet_model = LeNet5()
lenet_model.eval()

dummy_input = torch.rand(1, 1, 32, 32)

# %%
# Export to ONNX:
torch.onnx.export(
    lenet_model,                    # model
    dummy_input,                    # input example
    './sources/lenet5_cnn.onnx',    # save path
    input_names=['input'],          # name of input
    output_names=['output'],        # name of output
    opset_version=18,               # ONNX version
)
# Out:
# [torch.onnx] Obtain model graph for `LeNet5([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `LeNet5([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 18},
#             producer_name='pytorch',
#             producer_version='2.9.1+cu128',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"input"<FLOAT,[1,1,32,32]>
#             ),
#             outputs=(
#                 %"output"<FLOAT,[1,10]>
#             ),
#             initializers=(
#                 %"feature_extractor.0.weight"<FLOAT,[6,1,5,5]>{TorchTensor(...)},
#                 %"feature_extractor.0.bias"<FLOAT,[6]>{TorchTensor<FLOAT,[6]>(Parameter containing: tensor([-0.0328,  0.1937,  0.0902, -0.0216,  0.1665, -0.1277], requires_grad=True), name='feature_extractor.0.bias')},
#                 %"feature_extractor.3.weight"<FLOAT,[16,6,5,5]>{TorchTensor(...)},
#                 %"feature_extractor.3.bias"<FLOAT,[16]>{TorchTensor(...)},
#                 %"linears.0.weight"<FLOAT,[120,400]>{TorchTensor(...)},
#                 %"linears.0.bias"<FLOAT,[120]>{TorchTensor(...)},
#                 %"linears.2.weight"<FLOAT,[84,120]>{TorchTensor(...)},
#                 %"linears.2.bias"<FLOAT,[84]>{TorchTensor(...)},
#                 %"linears.4.weight"<FLOAT,[10,84]>{TorchTensor(...)},
#                 %"linears.4.bias"<FLOAT,[10]>{TorchTensor<FLOAT,[10]>(Parameter containing: tensor([ 0.0174,  0.1014, -0.0164, -0.0497,  0.0722,  0.0888,  0.0700, -0.0351, -0.0310,  0.0277], requires_grad=True), name='linears.4.bias')},
#                 %"val_3"<INT64,[2]>{Tensor<INT64,[2]>(array([  1, 400]), name='val_3')}
#             ),
#         ) {
#              0 |  # node_conv2d
#                   %"conv2d"<FLOAT,[1,6,28,28]> ⬅️ ::Conv(%"input", %"feature_extractor.0.weight"{...}, %"feature_extractor.0.bias"{[-0.0328233502805233, 0.1937413513660431, 0.09020622074604034, -0.02156534232199192, 0.16645441949367523, -0.12767080962657928]}) {group=1, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              1 |  # node_tanh
#                   %"tanh"<FLOAT,[1,6,28,28]> ⬅️ ::Tanh(%"conv2d")
#              2 |  # node_avg_pool2d
#                   %"avg_pool2d"<FLOAT,[1,6,14,14]> ⬅️ ::AveragePool(%"tanh") {count_include_pad=1, ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#              3 |  # node_conv2d_1
#                   %"conv2d_1"<FLOAT,[1,16,10,10]> ⬅️ ::Conv(%"avg_pool2d", %"feature_extractor.3.weight"{...}, %"feature_extractor.3.bias"{...}) {group=1, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              4 |  # node_tanh_1
#                   %"tanh_1"<FLOAT,[1,16,10,10]> ⬅️ ::Tanh(%"conv2d_1")
#              5 |  # node_avg_pool2d_1
#                   %"avg_pool2d_1"<FLOAT,[1,16,5,5]> ⬅️ ::AveragePool(%"tanh_1") {count_include_pad=1, ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#              6 |  # node_view
#                   %"view"<FLOAT,[1,400]> ⬅️ ::Reshape(%"avg_pool2d_1", %"val_3"{[1, 400]}) {allowzero=1}
#              7 |  # node_linear
#                   %"linear"<FLOAT,[1,120]> ⬅️ ::Gemm(%"view", %"linears.0.weight"{...}, %"linears.0.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#              8 |  # node_tanh_2
#                   %"tanh_2"<FLOAT,[1,120]> ⬅️ ::Tanh(%"linear")
#              9 |  # node_linear_1
#                   %"linear_1"<FLOAT,[1,84]> ⬅️ ::Gemm(%"tanh_2", %"linears.2.weight"{...}, %"linears.2.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             10 |  # node_tanh_3
#                   %"tanh_3"<FLOAT,[1,84]> ⬅️ ::Tanh(%"linear_1")
#             11 |  # node_linear_2
#                   %"output"<FLOAT,[1,10]> ⬅️ ::Gemm(%"tanh_3", %"linears.4.weight"{...}, %"linears.4.bias"{[0.017449351027607918, 0.10139334946870804, -0.01642262004315853, -0.04968580603599548, 0.07217240333557129, 0.0888138934969902, 0.0699620395898819, -0.03510943800210953, -0.030980052426457405, 0.027670497074723244]}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             return %"output"<FLOAT,[1,10]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_feature_extractor_0_weight: "f32[6, 1, 5, 5]", p_feature_extractor_0_bias: "f32[6]", p_feature_extractor_3_weight: "f32[16, 6, 5, 5]", p_feature_extractor_3_bias: "f32[16]", p_linears_0_weight: "f32[120, 400]", p_linears_0_bias: "f32[120]", p_linears_2_weight: "f32[84, 120]", p_linears_2_bias: "f32[84]", p_linears_4_weight: "f32[10, 84]", p_linears_4_bias: "f32[10]", x: "f32[1, 1, 32, 32]"):
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d: "f32[1, 6, 28, 28]" = torch.ops.aten.conv2d.default(x, p_feature_extractor_0_weight, p_feature_extractor_0_bias);  x = p_feature_extractor_0_weight = p_feature_extractor_0_bias = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/activation.py:430 in forward, code: return torch.tanh(input)
#                     tanh: "f32[1, 6, 28, 28]" = torch.ops.aten.tanh.default(conv2d);  conv2d = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/pooling.py:781 in forward, code: return F.avg_pool2d(
#                     avg_pool2d: "f32[1, 6, 14, 14]" = torch.ops.aten.avg_pool2d.default(tanh, [2, 2], [2, 2]);  tanh = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_1: "f32[1, 16, 10, 10]" = torch.ops.aten.conv2d.default(avg_pool2d, p_feature_extractor_3_weight, p_feature_extractor_3_bias);  avg_pool2d = p_feature_extractor_3_weight = p_feature_extractor_3_bias = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/activation.py:430 in forward, code: return torch.tanh(input)
#                     tanh_1: "f32[1, 16, 10, 10]" = torch.ops.aten.tanh.default(conv2d_1);  conv2d_1 = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/pooling.py:781 in forward, code: return F.avg_pool2d(
#                     avg_pool2d_1: "f32[1, 16, 5, 5]" = torch.ops.aten.avg_pool2d.default(tanh_1, [2, 2], [2, 2]);  tanh_1 = None
#
#                      # File: /tmp/ipykernel_70230/2591662210.py:42 in forward, code: out = torch.flatten(out, 1)
#                     view: "f32[1, 400]" = torch.ops.aten.view.default(avg_pool2d_1, [1, 400]);  avg_pool2d_1 = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear: "f32[1, 120]" = torch.ops.aten.linear.default(view, p_linears_0_weight, p_linears_0_bias);  view = p_linears_0_weight = p_linears_0_bias = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/activation.py:430 in forward, code: return torch.tanh(input)
#                     tanh_2: "f32[1, 120]" = torch.ops.aten.tanh.default(linear);  linear = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_1: "f32[1, 84]" = torch.ops.aten.linear.default(tanh_2, p_linears_2_weight, p_linears_2_bias);  tanh_2 = p_linears_2_weight = p_linears_2_bias = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/activation.py:430 in forward, code: return torch.tanh(input)
#                     tanh_3: "f32[1, 84]" = torch.ops.aten.tanh.default(linear_1);  linear_1 = None
#
#                      # File: /home/msalena/SFMaga/main_repo/cv_nn/.venv_cv_nn/lib/python3.12/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_2: "f32[1, 10]" = torch.ops.aten.linear.default(tanh_3, p_linears_4_weight, p_linears_4_bias);  tanh_3 = p_linears_4_weight = p_linears_4_bias = None
#                     return (linear_2,)
#
#         Graph signature:
#             # inputs
#             p_feature_extractor_0_weight: PARAMETER target='feature_extractor.0.weight'
#             p_feature_extractor_0_bias: PARAMETER target='feature_extractor.0.bias'
#             p_feature_extractor_3_weight: PARAMETER target='feature_extractor.3.weight'
#             p_feature_extractor_3_bias: PARAMETER target='feature_extractor.3.bias'
#             p_linears_0_weight: PARAMETER target='linears.0.weight'
#             p_linears_0_bias: PARAMETER target='linears.0.bias'
#             p_linears_2_weight: PARAMETER target='linears.2.weight'
#             p_linears_2_bias: PARAMETER target='linears.2.bias'
#             p_linears_4_weight: PARAMETER target='linears.4.weight'
#             p_linears_4_bias: PARAMETER target='linears.4.bias'
#             x: USER_INPUT
#
#             # outputs
#             linear_2: USER_OUTPUT
#
#         Range constraints: {}
#
# )

# %% [markdown]
# # Анализ графа вычислений в Netron

# %% [markdown]
# Схема сделана с помощью [Netron](https://netron.app/) и сохранена также в папке source под названием lenet5_cnn.onnx.png
#
# ![lenet5_cnn.onnx.png](attachment:lenet5_cnn.onnx.png)

# %% [markdown]
# Таким образом граф отражает LeNet-5 сеть:
# - **Всего слоев**: 7
#     - **Сверточных слоев**: 2
#         1. 6@28*28 (kernel=5, padding=0, stride=1)
#         2. 16@10*10 (kernel=5, padding=0, stride=1)
#     - **Пулинг слоев**: 2
#         1. 6@14*14 (kernel=2, stride=2)
#         2. 16@5*5 (kernel=2, stride=2)
#     - **Линейных слоев**: 3
#         1. 400*120
#         2. 120*84
#         3. 84*10
# - **Функция активации**: тангенс после кадого сверточного и линейного слоев
# - **[Дополнительно] Флаттен**: 1

# %% [markdown]
# # Контрольные вопросы

# %% [markdown]
# 1. Сколько параметров содержится в каждом свёрточном слое?
#     ```bash
#     Формула подсчета параметров:
#         (in_channels × out_channels × kernel_size[0] × kernel_size[1]) + out_channels
#     В первом сверточном слое -> (1*6*5*5)+6 = 156
#     Во втором сверточном слое -> (6*16*5*5)+16 = 2406
#     ```
#
#
# 2. Как влияет MaxPool2d на размер выходного тензора?
#     ```bash
#     MaxPool2d (как и AvgPool2d в моем случае) уменьшает пространственные размеры по формуле:
#         output_size = floor((input_size + 2 x padding - kernel_size) / stride) + 1
#     В первом пулинг слое -> ((28+2*0-2)/1)+1 = 14
#     Во втором пулинг слое -> ((10+2*0-2)/1)+1 = 5
#     ```
# 3. Что произойдёт при изменении количества выходных каналов в первом Conv2d?
#     ```bash
#     Рассмотрим на примере увеличения выходных каналов.
#     Физически:
#         Пусть новый out_channels=12, тогда:
#          - колиечство параметров первого слоя: (1*12*5*5)+12 = 312
#          - выход первого слоя: 12@28x28
#          - у второго сверточного слоя: in_channels = 12
#     По сути:
#         Увеличит вычислительную сложность и объем потребляемой памяти, но потенциально повысит выразительность модели
#     ```
# 4. Чем отличается eval() от train() режимов в PyTorch?
#     ```bash
#     train используется для обучения, тогда как eval - для валидации, отключая dropout и обновление running states
#     ```
# 5. Какие преимущества даёт экспорт в формат ONNX?
#     Основное преимущества - наглядность визуализации
#     ```
